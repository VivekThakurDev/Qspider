# %% [markdown]
# # Array problem
# 1) Reverse the array
#    -> 1) Reverse Right
#    -> 2) Reverse Left
#
# 2) shift 0,1 and 2 [dutch flag]
# 3) shift 0 in array
# 4) frequency of each element
#     -> 1) Max Frequency element
#     -> 2) majority element
#     -> 3) First non repeated element
#
# 5) two sum
# 6) Sum/Product of each element Execpt self
# 7) first missing reverse number
# 8) contains with most water
# 9) trapping rain water
# 10) Sorting
#    -> Bubble sort
#    -> Insertion sort
#    -> merge sort
#    -> Quick sort
#    -> selection sort
#
# 11) Binary search
# 12) second biggest element

# %% [markdown]
# other important Question
#
# 1) store n prime number/ fibonnic  series sums number in array
# 2) Sort array by increasing frequency
# 3) Merge two array
#     -> ZigZag manner
#     -> two sorted array in sorted manner
#
# 4) maximum sum array
# 5) maximum product array
