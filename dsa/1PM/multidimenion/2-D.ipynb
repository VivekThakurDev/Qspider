# %%
n= [
    [7,5,8,6,5,4],
    [9,6,8,5,4,7],
    [9,8,7,5,4,8]
]

def print_element(a):
    row=len(a)
    col=len(a[0])
    for i in range(row):
        for j in range(col):
            print(a[i][j],end='\t')
        print()
print(print_element(n))
# Out:
# 7	5	8	6	5	4
# 9	6	8	5	4	7
# 9	8	7	5	4	8
# None

# %%
# Transpose
def print_element(a):
    row=len(a)
    col=len(a[0])
    for i in range(row):
        for j in range(col):
            print(a[i][j],end='\t')
        print()
print(print_element(n))

print()
def print_element(a):
    row=len(a)
    col=len(a[0])
    for i in range(col):
        for j in range(row):
            print(a[j][i],end='\t')
        print()
print(print_element(n))


n =[
    [7,5,8,4,8],
    [9,6,8,5,7],
    [9,8,7,5,8]
]
# Out:
# 7	5	8	4	8
# 9	6	8	5	7
# 9	8	7	5	8
# None
#
# 7	9	9
# 5	6	8
# 8	8	7
# 4	5	5
# 8	7	8
# None

# %%
#  Binary Search in Matrix

def searchmatrix(matrix,target):
    row=len(matrix)
    col=len(matrix[0])
    start=0
    end= row*col-1
    while start<=end:
        mid=(start+end)//2
        r=mid//col
        c=mid%col
        if matrix[r][c]==target:
            return True
        elif matrix[r][c]<target:
            end=mid-1
        else:
            start=mid+1
    return False

n =[
    [7,5,8,4,8],
    [9,6,8,5,7],
    [9,8,7,5,8]
]
print(searchmatrix(n,5))
# Out:
# True

# %%
#Sort matrix row wise
def sortrow(a):
    n=len(a)
    for i in range(n):
        pivot=a[i]
        j=i-1
        while j>=0 and pivot<a[j]:
            a[j+1]=a[j]
            j-=1
        a[j+1]=pivot
    return a
# Out:
# 7	9	9
# 5	6	8
# 8	8	7
# 4	5	5
# 8	7	8
# None
