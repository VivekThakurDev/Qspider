# %%
import pandas as pd

# %%
hr = pd.read_csv('https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Practice/hr_data.csv')

# %%
hr
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %%
## GroupBy  : group by is used when we want to split the data into group based on column
##  syntax : var = var1.groupby('categorical_column')
##            var.groups
###            var.get_group('group_name')

# %%
dept= hr.groupby('department')
dept.groups
dept.get_group('sales')
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14967        87507               2                   128                   3
# 14968        87518               2                   128                   3
# 14969        87520               2                   157                   3
# 14970        87530               4                   225                   5
# 14971        87533               2                   140                   3
#
# ...

# %%
hr['salary'].unique()
# Out:
# <ArrowStringArray>
# ['low', 'medium', 'high']
# Length: 3, dtype: str

# %%
salary= hr.groupby('salary')
salary.get_group('low')
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# 5             1060               2                   153                   3
# 6             1061               6                   247                   4
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %%
titnic=pd.read_csv('https://github.com/Taj1920/Data-Analysis-Datasets/raw/refs/heads/main/Datasets-Practice/titanic.csv')

# %%
titnic
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived
# ...

# %%
titnic['embarked'].unique()
# Out:
# <ArrowStringArray>
# ['S', 'C', nan, 'Q']
# Length: 4, dtype: str

# %%
titnic.dropna(inplace=True)

# %%
titnic['embarked'].unique()
# Out:
# <ArrowStringArray>
# ['S', 'C', 'Q']
# Length: 3, dtype: str

# %%
tia= titnic.groupby('embarked')
tia.get_group('S')
# Out:
#       pclass                                               name     sex  \
# 0          1                      Allen, Miss. Elisabeth Walton  female
# 1          1                     Allison, Master. Hudson Trevor    male
# 2          1                       Allison, Miss. Helen Loraine  female
# 3          1               Allison, Mr. Hudson Joshua Creighton    male
# 4          1    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                                ...     ...
# 1188       3  Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...  female
# 1189       3                    Sandstrom, Miss. Marguerite Rut  female
# 1217       3         Soholt, Mr. Peter Andreas Lauritz Andersen    male
# 1230       3                         Strom, Miss. Telma Matilda  female
# 1231       3         Strom, Mrs. Wilhelm (Elna Matilda Persson)  female
#
#           age  sibsp  parch   ticket      fare    cabin embarked  survived
# ...

# %%
### Groupby multiple value 
## var1 = var.groupby(['col1','col2'])
## var1.groups
# var1.get_group((val1,val2))

# %%
hrs= hr.groupby(['department','salary'])
hrs.groups
hrs.get_group(('sales','high'))
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 696           4979               7                   291                   4
# 774           5398               2                   152                   3
# 852           5884               5                   217                   5
# 930           6370               5                   271                   5
# 1008          6835               4                   256                   5
# ...            ...             ...                   ...                 ...
# 13929        81338               4                   182                   3
# 13940         8304               5                   231                   7
# 13944         8848               5                   160                   3
# 13948        11277               3                   215                   6
# 14121        82500               4                   211                   7
#
# ...

# %%
### Data Aggrigation:
###  1) sum():- It will  return the sum of all values
###   2) mean():- It will return average values
###  3) meadian():- It 
###  4) mode():- most occarant value
###  5) count():- count of not null  values
###  6) min(): it will return  minumn value
###  7) max(): it will return maximum value

# %%
hr['time_spend_company'].max()
# Out:
# 10

# %%
## find the number of employee who left the company
hr[hr['left']==1]['left'].count()
# Out:
# np.int64(3571)

# %%
hr['left'].unique()
# Out:
# array([1, 0])

# %%
hr[hr['salary']=='low']['salary'].count()
# Out:
# np.int64(7316)

# %%
hres=hr.groupby('salary')
hres.get_group('low')['salary'].count()
# Out:
# np.int64(7316)

# %%
## no of employee in sales deptarment
hr.groupby('department')['department'].count()
# Out:
# department
# IT             1227
# RandD           787
# accounting      767
# hr              739
# management      630
# marketing       858
# product_mng     902
# sales          4140
# support        2229
# technical      2720
# Name: department, dtype: int64
