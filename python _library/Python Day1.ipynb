# %% [markdown]
# ## Numpy Day-1

# %%
# NUm stands for numberic or array

# PY  stands for python

# %%
# we will perform two task 
# 1 creating array 
# 2 Performing Operation on array 
'''

'''
# Out:
# '\n\n'

# %%
import numpy as np

# %%
# to know the version  of numpy(it will return the current version of the library )
np.__version__
# Out:
# '2.4.2'

# %%
# how to create a array 
# syntax to create a array :-  np.array(collection)
a=[1,2,3,4,5]

# %%
b=np.array(a)

# %%
print('a',type(a))
# Out:
# a <class 'list'>

# %% [raw]
#  difference between array and list
#
# array
# -> it consist only homogenous data
# -> we can perform almost all operation on array
# -> it stores the data in continous memory location.
# -> accessing  the value in array is fast.
#
# list
# -> it is a collection of homogeneous and hetrogeneous data ,
# -> we can perform limited operation  on list
# -> it stores the data in discontinous memory location.
# -> accessing  the value in list is slow

# %% [markdown]
# #### Data type priority
#  >str > Complex > Float > int> bool

# %%
a=np.array([True,False,3,7,4.5,4-3j,'hello'])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
type(a[1])
# Out:
# numpy.str_

# %%
a=np.array([True,False,3,7,4.5,4-3j])
type(a[1])
# Out:
# numpy.complex128

# %%
a=np.array([True,False,3,7,4.5,])
type(a[1])
# Out:
# numpy.float64

# %%
a=np.array([True,False,3,7])
type(a[1])
# Out:
# numpy.int64

# %%
a=np.array([True,False])
type(a[1])
# Out:
# numpy.bool

# %% [markdown]
# #### Trying operation  in array

# %%
a=np.array([2,3,5,4])
b=np.array([5,8,8,5])

# %%
a+b
# Out:
# array([ 7, 11, 13,  9])

# %%
a-b
# Out:
# array([-3, -5, -3, -1])

# %% [markdown]
# ### Types of Array

# %% [raw]
# 1. Uni Dimensional Array(1D)
# 2. Bi-Dimensional Array(2D)
# 3. Multi-Dimensional Array(3D)

# %% [markdown]
# #### 1D array

# %%
a=np.array([1,2,5,5,7,5])

# %%
a
# Out:
# array([1, 2, 5, 5, 7, 5])

# %% [markdown]
# #### 2D Array

# %%
b=np.array([[2,3,5,4],
           [2,4,5,7]])

# %%
b
# Out:
# array([[2, 3, 5, 4],
#        [2, 4, 5, 7]])

# %% [markdown]
# ### 3D Array

# %%
c=np.array([
              [[1,2,3,4],[2,5,4,5]],
              [[1,4,5,7],[1,4,5,4]],
              [[1,4,5,7],[1,4,5,4]]
         ])

# %%
# to check the dimensition of the array 
#var.ndim
c.ndim
# Out:
# 3

# %%
c
# Out:
# array([[[1, 2, 3, 4],
#         [2, 5, 4, 5]],
#
#        [[1, 4, 5, 7],
#         [1, 4, 5, 4]],
#
#        [[1, 4, 5, 7],
#         [1, 4, 5, 4]]])
