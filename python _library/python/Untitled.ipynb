# %%
def oc():
    n= input('enter the string')
    out={}
    for i in n: 
        if i not in out :
            out[i]==1
        else:
            out[i]+=1
    print(out)
oc()
# Out:
# enter the string cici
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 10
#       8             out[i]+=1
#       9     print(out)
# ---> 10 oc()
#
# Cell In[2], line 6, in oc()
#       4 for i in n:
#       5     if i not in out :
# ----> 6         out[i]==1
#       7     else:
#       8         out[i]+=1
#
# KeyError: 'c'
